# %% [markdown]
# # Linear Web Crawls with Dates
#
# In this section, we will look at using the `datetime` modules to create many urls that are based on dates.

# %% [markdown]
# ## The Problem
#
# * We have to create many urls based on dates/time.
#     * Example: `http://www.thecurrent.org/playlist/2014-01-01/01`
# * Working with dates is tough
#     * different days per month
#     * leap years

# %% [markdown]
# ## The solution
#
# We can use the `datetime` module to
#
# * Create many dates
# * Print to a specific output

# %%
import datetime

# %% [markdown]
# ## Example - Scraping The Current
#
# In a previous lab, we wrote a function get the information for a single page (1 hour of songs).  Here is the resulting functions.

# %%
import requests
from bs4 import BeautifulSoup

def get_period(soup):
    search = soup('span', class_="hour-header open")
    if len(search) > 0:
        return search[0].next.split('to')[0].rstrip()[-2:]
    else:
        return None

def get_day(soup):
    search = soup('a', class_="start-picker")
    if len(search) > 0:
        return search[0].next.split(',')[0]
    else:
        return None
    
def get_song_info(url):
    print("Starting {0} urls".format(url))
    date = url.split('/')[-2]
    s = requests.Session()
    r = s.get(url)
    soup = BeautifulSoup(r.content, 'lxml')
    period = get_period(soup)
    day_of_week = get_day(soup)
    soup = BeautifulSoup(r.content)
    titles = [t.next.strip() for t in soup.findAll('h5', class_="title")]
    artists = [a.next.strip() for a in soup.findAll('h5',class_='artist')]
    times = [d.time.next.strip() for d in soup('div', class_="two columns songTime")]
    song_info = [(day_of_week, date, time, period, title, artist) 
             for time, title, artist in zip(times, titles, artists)]
    return song_info

# %% [markdown]
# # Collecting a weeks worth of music
#
# ## Step 1 - Identify the url pattern
#
# The Current uses urls of the following pattern
#
#     'http://www.thecurrent.org/playlist/2017-05-04/10'
#
# or
#
#     'http://www.thecurrent.org/playlist/year-month-day/hour'

# %% [markdown]
# ## Question: How might you generate all combinations for a given year?
#
# **Answer:** Python has a tool for that!

# %%
numdays = 7
# Set the base url as today
base = datetime.datetime.today()
# Make new times by subracting an hour at a time.
dts = [base - datetime.timedelta(hours = h) for h in range(0, numdays*24)]
dts
# Out:
# [datetime.datetime(2020, 10, 27, 11, 37, 15, 290502),
#  datetime.datetime(2020, 10, 27, 10, 37, 15, 290502),
#  datetime.datetime(2020, 10, 27, 9, 37, 15, 290502),
#  datetime.datetime(2020, 10, 27, 8, 37, 15, 290502),
#  datetime.datetime(2020, 10, 27, 7, 37, 15, 290502),
#  datetime.datetime(2020, 10, 27, 6, 37, 15, 290502),
#  datetime.datetime(2020, 10, 27, 5, 37, 15, 290502),
#  datetime.datetime(2020, 10, 27, 4, 37, 15, 290502),
#  datetime.datetime(2020, 10, 27, 3, 37, 15, 290502),
#  datetime.datetime(2020, 10, 27, 2, 37, 15, 290502),
#  datetime.datetime(2020, 10, 27, 1, 37, 15, 290502),
#  datetime.datetime(2020, 10, 27, 0, 37, 15, 290502),
#  datetime.datetime(2020, 10, 26, 23, 37, 15, 290502),
#  datetime.datetime(2020, 10, 26, 22, 37, 15, 290502),
#  datetime.datetime(2020, 10, 26, 21, 37, 15, 290502),
#  datetime.datetime(2020, 10, 26, 20, 37, 15, 290502),
#  datetime.datetime(2020, 10, 26, 19, 37, 15, 290502),
#  datetime.datetime(2020, 10, 26, 18, 37, 15, 290502),
#  datetime.datetime(2020, 10, 26, 17, 37, 15, 290502),
#  datetime.datetime(2020, 10, 26, 16, 37, 15, 290502),
#  datetime.datetime(2020, 10, 26, 15, 37, 15, 290502),
#  datetime.datetime(2020, 10, 26, 14, 37, 15, 290502),
#  datetime.datetime(2020, 10, 26, 13, 37, 15, 290502),
#  datetime.datetime(2020, 10, 26, 12, 37, 15, 290502),
#  datetime.datetime(2020, 10, 26, 11, 37, 15, 290502),
#  datetime.datetime(2020, 10, 26, 10, 37, 15, 290502),
#  datetime.datetime(2020, 10, 26, 9, 37, 15, 290502),
#  datetime.datetime(2020, 10, 26, 8, 37, 15, 290502),
#  datetime.datetime(2020, 10, 26, 7, 37, 15, 290502),
#  datetime.datetime(2020, 10, 26, 6, 37, 15, 290502),
#  datetime.datetime(2020, 10, 26, 5, 37, 15, 290502),
#  datetime.datetime(2020, 10, 26, 4, 37, 15, 290502),
#  datetime.datetime(2020, 10, 26, 3, 37, 15, 290502),
#  datetime.datetime(2020, 10, 26, 2, 37, 15, 290502),
#  datetime.datetime(2020, 10, 26, 1, 37, 15, 290502),
#  datetime.datetime(2020, 10, 26, 0, 37, 15, 290502),
#  datetime.datetime(2020, 10, 25, 23, 37, 15, 290502),
#  datetime.datetime(2020, 10, 25, 22, 37, 15, 290502),
#  datetime.datetime(2020, 10, 25, 21, 37, 15, 290502),
#  datetime.datetime(2020, 10, 25, 20, 37, 15, 290502),
#  datetime.datetime(2020, 10, 25, 19, 37, 15, 290502),
#  datetime.datetime(2020, 10, 25, 18, 37, 15, 290502),
#  datetime.datetime(2020, 10, 25, 17, 37, 15, 290502),
#  datetime.datetime(2020, 10, 25, 16, 37, 15, 290502),
#  datetime.datetime(2020, 10, 25, 15, 37, 15, 290502),
#  datetime.datetime(2020, 10, 25, 14, 37, 15, 290502),
#  datetime.datetime(2020, 10, 25, 13, 37, 15, 290502),
#  datetime.datetime(2020, 10, 25, 12, 37, 15, 290502),
#  datetime.datetime(2020, 10, 25, 11, 37, 15, 290502),
#  datetime.datetime(2020, 10, 25, 10, 37, 15, 290502),
#  datetime.datetime(2020, 10, 25, 9, 37, 15, 290502),
#  datetime.datetime(2020, 10, 25, 8, 37, 15, 290502),
#  datetime.datetime(2020, 10, 25, 7, 37, 15, 290502),
#  datetime.datetime(2020, 10, 25, 6, 37, 15, 290502),
#  datetime.datetime(2020, 10, 25, 5, 37, 15, 290502),
#  datetime.datetime(2020, 10, 25, 4, 37, 15, 290502),
#  datetime.datetime(2020, 10, 25, 3, 37, 15, 290502),
#  datetime.datetime(2020, 10, 25, 2, 37, 15, 290502),
#  datetime.datetime(2020, 10, 25, 1, 37, 15, 290502),
#  datetime.datetime(2020, 10, 25, 0, 37, 15, 290502),
#  datetime.datetime(2020, 10, 24, 23, 37, 15, 290502),
#  datetime.datetime(2020, 10, 24, 22, 37, 15, 290502),
#  datetime.datetime(2020, 10, 24, 21, 37, 15, 290502),
#  datetime.datetime(2020, 10, 24, 20, 37, 15, 290502),
#  datetime.datetime(2020, 10, 24, 19, 37, 15, 290502),
#  datetime.datetime(2020, 10, 24, 18, 37, 15, 290502),
#  datetime.datetime(2020, 10, 24, 17, 37, 15, 290502),
#  datetime.datetime(2020, 10, 24, 16, 37, 15, 290502),
#  datetime.datetime(2020, 10, 24, 15, 37, 15, 290502),
#  datetime.datetime(2020, 10, 24, 14, 37, 15, 290502),
#  datetime.datetime(2020, 10, 24, 13, 37, 15, 290502),
#  datetime.datetime(2020, 10, 24, 12, 37, 15, 290502),
#  datetime.datetime(2020, 10, 24, 11, 37, 15, 290502),
#  datetime.datetime(2020, 10, 24, 10, 37, 15, 290502),
#  datetime.datetime(2020, 10, 24, 9, 37, 15, 290502),
#  datetime.datetime(2020, 10, 24, 8, 37, 15, 290502),
#  datetime.datetime(2020, 10, 24, 7, 37, 15, 290502),
#  datetime.datetime(2020, 10, 24, 6, 37, 15, 290502),
#  datetime.datetime(2020, 10, 24, 5, 37, 15, 290502),
#  datetime.datetime(2020, 10, 24, 4, 37, 15, 290502),
#  datetime.datetime(2020, 10, 24, 3, 37, 15, 290502),
#  datetime.datetime(2020, 10, 24, 2, 37, 15, 290502),
#  datetime.datetime(2020, 10, 24, 1, 37, 15, 290502),
#  datetime.datetime(2020, 10, 24, 0, 37, 15, 290502),
#  datetime.datetime(2020, 10, 23, 23, 37, 15, 290502),
#  datetime.datetime(2020, 10, 23, 22, 37, 15, 290502),
#  datetime.datetime(2020, 10, 23, 21, 37, 15, 290502),
#  datetime.datetime(2020, 10, 23, 20, 37, 15, 290502),
#  datetime.datetime(2020, 10, 23, 19, 37, 15, 290502),
#  datetime.datetime(2020, 10, 23, 18, 37, 15, 290502),
#  datetime.datetime(2020, 10, 23, 17, 37, 15, 290502),
#  datetime.datetime(2020, 10, 23, 16, 37, 15, 290502),
#  datetime.datetime(2020, 10, 23, 15, 37, 15, 290502),
#  datetime.datetime(2020, 10, 23, 14, 37, 15, 290502),
#  datetime.datetime(2020, 10, 23, 13, 37, 15, 290502),
#  datetime.datetime(2020, 10, 23, 12, 37, 15, 290502),
#  datetime.datetime(2020, 10, 23, 11, 37, 15, 290502),
#  datetime.datetime(2020, 10, 23, 10, 37, 15, 290502),
#  datetime.datetime(2020, 10, 23, 9, 37, 15, 290502),
#  datetime.datetime(2020, 10, 23, 8, 37, 15, 290502),
#  datetime.datetime(2020, 10, 23, 7, 37, 15, 290502),
#  datetime.datetime(2020, 10, 23, 6, 37, 15, 290502),
#  datetime.datetime(2020, 10, 23, 5, 37, 15, 290502),
#  datetime.datetime(2020, 10, 23, 4, 37, 15, 290502),
#  datetime.datetime(2020, 10, 23, 3, 37, 15, 290502),
#  datetime.datetime(2020, 10, 23, 2, 37, 15, 290502),
#  datetime.datetime(2020, 10, 23, 1, 37, 15, 290502),
#  datetime.datetime(2020, 10, 23, 0, 37, 15, 290502),
#  datetime.datetime(2020, 10, 22, 23, 37, 15, 290502),
#  datetime.datetime(2020, 10, 22, 22, 37, 15, 290502),
#  datetime.datetime(2020, 10, 22, 21, 37, 15, 290502),
#  datetime.datetime(2020, 10, 22, 20, 37, 15, 290502),
#  datetime.datetime(2020, 10, 22, 19, 37, 15, 290502),
#  datetime.datetime(2020, 10, 22, 18, 37, 15, 290502),
#  datetime.datetime(2020, 10, 22, 17, 37, 15, 290502),
#  datetime.datetime(2020, 10, 22, 16, 37, 15, 290502),
#  datetime.datetime(2020, 10, 22, 15, 37, 15, 290502),
#  datetime.datetime(2020, 10, 22, 14, 37, 15, 290502),
#  datetime.datetime(2020, 10, 22, 13, 37, 15, 290502),
#  datetime.datetime(2020, 10, 22, 12, 37, 15, 290502),
#  datetime.datetime(2020, 10, 22, 11, 37, 15, 290502),
#  datetime.datetime(2020, 10, 22, 10, 37, 15, 290502),
#  datetime.datetime(2020, 10, 22, 9, 37, 15, 290502),
#  datetime.datetime(2020, 10, 22, 8, 37, 15, 290502),
#  datetime.datetime(2020, 10, 22, 7, 37, 15, 290502),
#  datetime.datetime(2020, 10, 22, 6, 37, 15, 290502),
#  datetime.datetime(2020, 10, 22, 5, 37, 15, 290502),
#  datetime.datetime(2020, 10, 22, 4, 37, 15, 290502),
#  datetime.datetime(2020, 10, 22, 3, 37, 15, 290502),
#  datetime.datetime(2020, 10, 22, 2, 37, 15, 290502),
#  datetime.datetime(2020, 10, 22, 1, 37, 15, 290502),
#  datetime.datetime(2020, 10, 22, 0, 37, 15, 290502),
#  datetime.datetime(2020, 10, 21, 23, 37, 15, 290502),
#  datetime.datetime(2020, 10, 21, 22, 37, 15, 290502),
#  datetime.datetime(2020, 10, 21, 21, 37, 15, 290502),
#  datetime.datetime(2020, 10, 21, 20, 37, 15, 290502),
#  datetime.datetime(2020, 10, 21, 19, 37, 15, 290502),
#  datetime.datetime(2020, 10, 21, 18, 37, 15, 290502),
#  datetime.datetime(2020, 10, 21, 17, 37, 15, 290502),
#  datetime.datetime(2020, 10, 21, 16, 37, 15, 290502),
#  datetime.datetime(2020, 10, 21, 15, 37, 15, 290502),
#  datetime.datetime(2020, 10, 21, 14, 37, 15, 290502),
#  datetime.datetime(2020, 10, 21, 13, 37, 15, 290502),
#  datetime.datetime(2020, 10, 21, 12, 37, 15, 290502),
#  datetime.datetime(2020, 10, 21, 11, 37, 15, 290502),
#  datetime.datetime(2020, 10, 21, 10, 37, 15, 290502),
#  datetime.datetime(2020, 10, 21, 9, 37, 15, 290502),
#  datetime.datetime(2020, 10, 21, 8, 37, 15, 290502),
#  datetime.datetime(2020, 10, 21, 7, 37, 15, 290502),
#  datetime.datetime(2020, 10, 21, 6, 37, 15, 290502),
#  datetime.datetime(2020, 10, 21, 5, 37, 15, 290502),
#  datetime.datetime(2020, 10, 21, 4, 37, 15, 290502),
#  datetime.datetime(2020, 10, 21, 3, 37, 15, 290502),
#  datetime.datetime(2020, 10, 21, 2, 37, 15, 290502),
#  datetime.datetime(2020, 10, 21, 1, 37, 15, 290502),
#  datetime.datetime(2020, 10, 21, 0, 37, 15, 290502),
#  datetime.datetime(2020, 10, 20, 23, 37, 15, 290502),
#  datetime.datetime(2020, 10, 20, 22, 37, 15, 290502),
#  datetime.datetime(2020, 10, 20, 21, 37, 15, 290502),
#  datetime.datetime(2020, 10, 20, 20, 37, 15, 290502),
#  datetime.datetime(2020, 10, 20, 19, 37, 15, 290502),
#  datetime.datetime(2020, 10, 20, 18, 37, 15, 290502),
#  datetime.datetime(2020, 10, 20, 17, 37, 15, 290502),
#  datetime.datetime(2020, 10, 20, 16, 37, 15, 290502),
#  datetime.datetime(2020, 10, 20, 15, 37, 15, 290502),
#  datetime.datetime(2020, 10, 20, 14, 37, 15, 290502),
#  datetime.datetime(2020, 10, 20, 13, 37, 15, 290502),
#  datetime.datetime(2020, 10, 20, 12, 37, 15, 290502)]

# %% [markdown]
# ## Outputing the time in a specific format.
#
# * datetime objects have a `strftime` method for outputing formatted dates
#     * `%Y` is the year in 4 digits
#     * `%m` is the month in 2 digits
#     * etc.
# * See [this site](https://docs.python.org/3/library/datetime.html#strftime-strptime-behavior) for more information.

# %%
fmt = 'http://www.thecurrent.org/playlist/%Y-%m-%d/%H'

date = datetime.datetime(2000,1,1,1)
date.strftime(fmt)
# Out:
# 'http://www.thecurrent.org/playlist/2000-01-01/01'

# %% [markdown]
# ## Let's make some functions

# %%
def output_address(dt):
    fmt = 'http://www.thecurrent.org/playlist/%Y-%m-%d/%H'
    return dt.strftime(fmt)

def test_output_address():
    date = datetime.datetime(2000,1,1,1)
    assert output_address(date) == 'http://www.thecurrent.org/playlist/2000-01-01/01'
test_output_address()

# %%
urls = [output_address(d) for d in dts]
urls[:10]
# Out:
# ['http://www.thecurrent.org/playlist/2020-10-27/11',
#  'http://www.thecurrent.org/playlist/2020-10-27/10',
#  'http://www.thecurrent.org/playlist/2020-10-27/09',
#  'http://www.thecurrent.org/playlist/2020-10-27/08',
#  'http://www.thecurrent.org/playlist/2020-10-27/07',
#  'http://www.thecurrent.org/playlist/2020-10-27/06',
#  'http://www.thecurrent.org/playlist/2020-10-27/05',
#  'http://www.thecurrent.org/playlist/2020-10-27/04',
#  'http://www.thecurrent.org/playlist/2020-10-27/03',
#  'http://www.thecurrent.org/playlist/2020-10-27/02']

# %%
info_lists = [get_song_info(url) for url in urls]
flat_info = [row for info_list in info_lists for row in info_list]
lines = [",".join(row) for row in flat_info]

with open('the_current_last_year.csv', 'w') as outfile:
    header = "Weekday,Date,Time,Period,Song_Title,Artist"
    print(header, file=outfile)
    count = 0
    for url in urls:
        for line in lines:
            count += 1
            if count % 5 == 0:
                print("Processed {0} songs".format(count))
            print(line, file=outfile)
# Out:
# Starting http://www.thecurrent.org/playlist/2020-10-27/11 urls
# Starting http://www.thecurrent.org/playlist/2020-10-27/10 urls
# Starting http://www.thecurrent.org/playlist/2020-10-27/09 urls
# Starting http://www.thecurrent.org/playlist/2020-10-27/08 urls
# Starting http://www.thecurrent.org/playlist/2020-10-27/07 urls
# Starting http://www.thecurrent.org/playlist/2020-10-27/06 urls
# Starting http://www.thecurrent.org/playlist/2020-10-27/05 urls
# Starting http://www.thecurrent.org/playlist/2020-10-27/04 urls
# Starting http://www.thecurrent.org/playlist/2020-10-27/03 urls
# Starting http://www.thecurrent.org/playlist/2020-10-27/02 urls
# Starting http://www.thecurrent.org/playlist/2020-10-27/01 urls
# Starting http://www.thecurrent.org/playlist/2020-10-27/00 urls
# Starting http://www.thecurrent.org/playlist/2020-10-26/23 urls
# Starting http://www.thecurrent.org/playlist/2020-10-26/22 urls
# Starting http://www.thecurrent.org/playlist/2020-10-26/21 urls
# Starting http://www.thecurrent.org/playlist/2020-10-26/20 urls
# Starting http://www.thecurrent.org/playlist/2020-10-26/19 urls
# Starting http://www.thecurrent.org/playlist/2020-10-26/18 urls
# Starting http://www.thecurrent.org/playlist/2020-10-26/17 urls
# Starting http://www.thecurrent.org/playlist/2020-10-26/16 urls
# Starting http://www.thecurrent.org/playlist/2020-10-26/15 urls
# Starting http://www.thecurrent.org/playlist/2020-10-26/14 urls
# Starting http://www.thecurrent.org/playlist/2020-10-26/13 urls
# Starting http://www.thecurrent.org/playlist/2020-10-26/12 urls
# Starting http://www.thecurrent.org/playlist/2020-10-26/11 urls
# Starting http://www.thecurrent.org/playlist/2020-10-26/10 urls
# Starting http://www.thecurrent.org/playlist/2020-10-26/09 urls
# Starting http://www.thecurrent.org/playlist/2020-10-26/08 urls
# Starting http://www.thecurrent.org/playlist/2020-10-26/07 urls
# Starting http://www.thecurrent.org/playlist/2020-10-26/06 urls
# Starting http://www.thecurrent.org/playlist/2020-10-26/05 urls
# Starting http://www.thecurrent.org/playlist/2020-10-26/04 urls
# Starting http://www.thecurrent.org/playlist/2020-10-26/03 urls
# Starting http://www.thecurrent.org/playlist/2020-10-26/02 urls
# Starting http://www.thecurrent.org/playlist/2020-10-26/01 urls
# Starting http://www.thecurrent.org/playlist/2020-10-26/00 urls
# Starting http://www.thecurrent.org/playlist/2020-10-25/23 urls
# Starting http://www.thecurrent.org/playlist/2020-10-25/22 urls
# Starting http://www.thecurrent.org/playlist/2020-10-25/21 urls
# Starting http://www.thecurrent.org/playlist/2020-10-25/20 urls
# Starting http://www.thecurrent.org/playlist/2020-10-25/19 urls
# Starting http://www.thecurrent.org/playlist/2020-10-25/18 urls
# Starting http://www.thecurrent.org/playlist/2020-10-25/17 urls
# Starting http://www.thecurrent.org/playlist/2020-10-25/16 urls
# Starting http://www.thecurrent.org/playlist/2020-10-25/15 urls
# Starting http://www.thecurrent.org/playlist/2020-10-25/14 urls
# Starting http://www.thecurrent.org/playlist/2020-10-25/13 urls
# Starting http://www.thecurrent.org/playlist/2020-10-25/12 urls
# Starting http://www.thecurrent.org/playlist/2020-10-25/11 urls
# Starting http://www.thecurrent.org/playlist/2020-10-25/10 urls
# Starting http://www.thecurrent.org/playlist/2020-10-25/09 urls
# Starting http://www.thecurrent.org/playlist/2020-10-25/08 urls
# Starting http://www.thecurrent.org/playlist/2020-10-25/07 urls
# Starting http://www.thecurrent.org/playlist/2020-10-25/06 urls
# Starting http://www.thecurrent.org/playlist/2020-10-25/05 urls
# Starting http://www.thecurrent.org/playlist/2020-10-25/04 urls
# Starting http://www.thecurrent.org/playlist/2020-10-25/03 urls
# Starting http://www.thecurrent.org/playlist/2020-10-25/02 urls
# Starting http://www.thecurrent.org/playlist/2020-10-25/01 urls
# Starting http://www.thecurrent.org/playlist/2020-10-25/00 urls
# Starting http://www.thecurrent.org/playlist/2020-10-24/23 urls
# Starting http://www.thecurrent.org/playlist/2020-10-24/22 urls
# Starting http://www.thecurrent.org/playlist/2020-10-24/21 urls
# Starting http://www.thecurrent.org/playlist/2020-10-24/20 urls
# Starting http://www.thecurrent.org/playlist/2020-10-24/19 urls
# Starting http://www.thecurrent.org/playlist/2020-10-24/18 urls
# Starting http://www.thecurrent.org/playlist/2020-10-24/17 urls
# Starting http://www.thecurrent.org/playlist/2020-10-24/16 urls
# Starting http://www.thecurrent.org/playlist/2020-10-24/15 urls
# Starting http://www.thecurrent.org/playlist/2020-10-24/14 urls
# Starting http://www.thecurrent.org/playlist/2020-10-24/13 urls
# Starting http://www.thecurrent.org/playlist/2020-10-24/12 urls
# Starting http://www.thecurrent.org/playlist/2020-10-24/11 urls
# Starting http://www.thecurrent.org/playlist/2020-10-24/10 urls
# Starting http://www.thecurrent.org/playlist/2020-10-24/09 urls
# Starting http://www.thecurrent.org/playlist/2020-10-24/08 urls
# Starting http://www.thecurrent.org/playlist/2020-10-24/07 urls
# Starting http://www.thecurrent.org/playlist/2020-10-24/06 urls
# Starting http://www.thecurrent.org/playlist/2020-10-24/05 urls
# Starting http://www.thecurrent.org/playlist/2020-10-24/04 urls
# Starting http://www.thecurrent.org/playlist/2020-10-24/03 urls
# Starting http://www.thecurrent.org/playlist/2020-10-24/02 urls
# Starting http://www.thecurrent.org/playlist/2020-10-24/01 urls
# Starting http://www.thecurrent.org/playlist/2020-10-24/00 urls
# Starting http://www.thecurrent.org/playlist/2020-10-23/23 urls
# Starting http://www.thecurrent.org/playlist/2020-10-23/22 urls
# Starting http://www.thecurrent.org/playlist/2020-10-23/21 urls
# Starting http://www.thecurrent.org/playlist/2020-10-23/20 urls
# Starting http://www.thecurrent.org/playlist/2020-10-23/19 urls
# Starting http://www.thecurrent.org/playlist/2020-10-23/18 urls
# Starting http://www.thecurrent.org/playlist/2020-10-23/17 urls
# Starting http://www.thecurrent.org/playlist/2020-10-23/16 urls
# Starting http://www.thecurrent.org/playlist/2020-10-23/15 urls
# Starting http://www.thecurrent.org/playlist/2020-10-23/14 urls
# Starting http://www.thecurrent.org/playlist/2020-10-23/13 urls
# Starting http://www.thecurrent.org/playlist/2020-10-23/12 urls
# Starting http://www.thecurrent.org/playlist/2020-10-23/11 urls
# Starting http://www.thecurrent.org/playlist/2020-10-23/10 urls
# Starting http://www.thecurrent.org/playlist/2020-10-23/09 urls
